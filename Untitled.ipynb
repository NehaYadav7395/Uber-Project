# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("Uber_Dataset_500.csv")

# %%
dataset
# Out:
#            START_DATE          END_DATE  CATEGORY          START         STOP  \
# 0    07/02/2016 01:22  07/02/2016 04:03  Business        Chicago      Atlanta
# 1    01/04/2016 05:27  01/04/2016 07:22  Personal        Houston     New York
# 2    07/14/2016 14:59  07/14/2016 16:51  Personal    Los Angeles      Chicago
# 3    02/03/2016 04:34  02/03/2016 05:52  Business        Chicago     New York
# 4    06/09/2016 16:00  06/09/2016 17:40  Business  San Francisco       Boston
# ..                ...               ...       ...            ...          ...
# 495  01/16/2016 14:11  01/16/2016 15:38  Personal       New York      Chicago
# 496  01/25/2016 20:18  01/25/2016 21:25  Personal        Atlanta       Dallas
# 497  02/05/2016 01:28  02/05/2016 01:59  Business  San Francisco     New York
# 498  05/31/2016 22:09  06/01/2016 00:29  Personal         Dallas      Seattle
# 499  06/01/2016 14:25  06/01/2016 17:21  Personal        Chicago  Los Angeles
#
#      MILES             PURPOSE
# 0     13.7             Commute
# 1      8.4             Commute
# 2     20.8             Meeting
# 3     29.0  Meal/Entertainment
# 4     22.6             Commute
# ..     ...                 ...
# 495   12.5      Customer Visit
# 496   13.4      Temporary Site
# 497   36.3             Meeting
# 498   29.3     Errand/Supplies
# 499   12.6      Customer Visit
#
# [500 rows x 7 columns]

# %%
dataset.shape
# Out:
# (500, 7)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  500 non-null    object
#  1   END_DATE    500 non-null    object
#  2   CATEGORY    500 non-null    object
#  3   START       500 non-null    object
#  4   STOP        500 non-null    object
#  5   MILES       500 non-null    float64
#  6   PURPOSE     500 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 27.5+ KB

# %%
dataset['START_DATE'] = pd.to_datetime(dataset['START_DATE'],errors= 'coerce')
dataset['END_DATE'] = pd.to_datetime(dataset['END_DATE'],errors = 'coerce')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  500 non-null    datetime64[ns]
#  1   END_DATE    500 non-null    datetime64[ns]
#  2   CATEGORY    500 non-null    object
#  3   START       500 non-null    object
#  4   STOP        500 non-null    object
#  5   MILES       500 non-null    float64
#  6   PURPOSE     500 non-null    object
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 27.5+ KB

# %%
from datetime import datetime

dataset['date'] = pd.DatetimeIndex(dataset['START_DATE']).date
dataset['time'] = pd.DatetimeIndex(dataset['START_DATE']).hour

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY          START      STOP  \
# 0 2016-07-02 01:22:00 2016-07-02 04:03:00  Business        Chicago   Atlanta
# 1 2016-01-04 05:27:00 2016-01-04 07:22:00  Personal        Houston  New York
# 2 2016-07-14 14:59:00 2016-07-14 16:51:00  Personal    Los Angeles   Chicago
# 3 2016-02-03 04:34:00 2016-02-03 05:52:00  Business        Chicago  New York
# 4 2016-06-09 16:00:00 2016-06-09 17:40:00  Business  San Francisco    Boston
#
#    MILES             PURPOSE        date  time
# 0   13.7             Commute  2016-07-02     1
# 1    8.4             Commute  2016-01-04     5
# 2   20.8             Meeting  2016-07-14    14
# 3   29.0  Meal/Entertainment  2016-02-03     4
# 4   22.6             Commute  2016-06-09    16

# %%
dataset['day-night'] = pd.cut(x=dataset['time'],bins= [0,10,15,19,24],labels = ['Morning','Afternoon','Evening','Night'])

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY          START      STOP  \
# 0 2016-07-02 01:22:00 2016-07-02 04:03:00  Business        Chicago   Atlanta
# 1 2016-01-04 05:27:00 2016-01-04 07:22:00  Personal        Houston  New York
# 2 2016-07-14 14:59:00 2016-07-14 16:51:00  Personal    Los Angeles   Chicago
# 3 2016-02-03 04:34:00 2016-02-03 05:52:00  Business        Chicago  New York
# 4 2016-06-09 16:00:00 2016-06-09 17:40:00  Business  San Francisco    Boston
#
#    MILES             PURPOSE        date  time  day-night
# 0   13.7             Commute  2016-07-02     1    Morning
# 1    8.4             Commute  2016-01-04     5    Morning
# 2   20.8             Meeting  2016-07-14    14  Afternoon
# 3   29.0  Meal/Entertainment  2016-02-03     4    Morning
# 4   22.6             Commute  2016-06-09    16    Evening

# %%
dataset.dropna(inplace = True)

# %%
dataset.shape
# Out:
# (479, 10)

# %% [markdown]
# #Data Visualcation

# %% [markdown]
# #which categorry and wich purpose ---

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)

sns.countplot(dataset['CATEGORY'])
plt.xticks(rotation=90)

plt.subplot(1,2,2)
sns.countplot(dataset['PURPOSE'])
# Out:
# <Axes: xlabel='count', ylabel='PURPOSE'>

# %% [markdown]
# #which timing

# %%
sns.countplot(dataset['day-night'])
# Out:
# <Axes: xlabel='count', ylabel='day-night'>
